# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from Algorithm import Kmeans, scaler, get_2D_graph

# %%
df = pd.read_csv(r'C:\Users\mpiernicki\PycharmProjects\K_Means_Algorithm\DATA\blob.csv')

# %%
color=['blue','green','cyan','yellow']
plt.scatter(df['x'],df['y'], c=df['color'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
df['color'].value_counts()
# Out:
# 3    1055
# 2    1045
# 1    1019
# 0     967
# Name: color, dtype: int64

# %%
df.drop(['color'], axis=1, inplace=True)

# %%
df.head()
# Out:
#             x           y
# 0  199.115034   72.641121
# 1  196.880523  247.744708
# 2   88.426271  233.962425
# 3  118.578789  264.044188
# 4  249.572490  260.896521

# %%
df.describe()
# Out:
#                  x            y
# count  4086.000000  4086.000000
# mean    189.870723   178.623157
# std      65.401912    64.963358
# min      47.191786    42.115898
# 25%     132.253424   123.035327
# 50%     190.950023   174.867601
# 75%     245.826004   234.976024
# max     341.567130   322.741088

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4086 entries, 0 to 4085
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       4086 non-null   float64
#  1   y       4086 non-null   float64
# dtypes: float64(2)
# memory usage: 64.0 KB

# %%
sns.pairplot(data=df)

# %%
df = scaler(df)

# %%
kmeans = Kmeans(df,4)

# %%
init_centers = kmeans.get_init_centers_plusplus()

# %%
init_centers
# Out:
#              x         y
# 1320  0.231197  0.528789
# 1     1.454491  0.896691
# 2     1.067110 -0.091138
# 3     0.630807  1.366759

# %%
labels, centers = kmeans.get_final_centers(init_centers)

# %%
print(labels)
# Out:
# [2 3 0 ... 2 2 0]

# %%
centers
# Out:
#              x         y
# 1320  0.366729  0.513250
# 1     1.096834  0.857633
# 2     0.932085  0.232791
# 3     0.608418  1.093566

# %%
df['color'] = labels.tolist()

# %%
color=['blue','green','cyan','yellow']
plt.scatter(df['x'],df['y'], c=labels)
plt.scatter(init_centers["x"],init_centers["y"],c='red')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
